# %%
from bs4 import BeautifulSoup
import requests
import sys
from collections import Counter

# %%
html = requests.get('http://web2.assist.org/web-assist/welcome.html').text

# %%
soup = BeautifulSoup(html,'html5lib')

# %%
first_paragraph = soup.find('select')
first_paragraph
# Out:
# <select name="ia" onchange="window.location=document.institution.ia.options[document.institution.ia.selectedIndex].value" onmouseout="hideHelpDiv('helptextINST1')" onmouseover="showHelpDiv('helptextINST1')" size="0" tabindex="1">
#         <option class="fontsize" selected="" value="">
#           Click here to select an institution</option>
#
#
#           <!-- Allan Hancock College -->
#           <option class="fontsize" value="AHC.html">Allan Hancock College</option>
#           <!-- American River College -->
#           <option class="fontsize" value="ARC.html">American River College</option>
#           <!-- Antelope Valley College -->
#           <option class="fontsize" value="AVC.html">Antelope Valley College</option>
#           <!-- Bakersfield College -->
#           <option class="fontsize" value="BAKERFLD.html">Bakersfield College</option>
#           <!-- Barstow Community College -->
# ...

# %%
schoolName = 'Diablo Valley College' 
first_paragraph[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-a66ffcfa1f3a> in <module>()
#       1 schoolName = 'Diablo Valley College'
# ----> 2 first_paragraph[1]
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\bs4\element.py in __getitem__(self, key)
#    1009         """tag[key] returns the value of the 'key' attribute for the tag,
#    1010         and throws an exception if it's not there."""
# -> 1011         return self.attrs[key]
#    1012
#    1013     def __iter__(self):
#
# KeyError: 1
