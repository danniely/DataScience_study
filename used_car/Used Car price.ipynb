# %%
import math
from collections import Counter
from matplotlib import pyplot as plt
import random
import pandas as pd
import os
import sys
import csv
import dateutil.parser
module_path1 = os.path.abspath(os.path.join('C:\\Users\\Danniel\\Documents\\GitHub\\DataScience_study\\data_science_package'))
if module_path1 not in sys.path:
    sys.path.append(module_path1)
from Statistics import correlation
from collections import Counter
import numpy as np

# %% [markdown]
# In this module, we are going to explore the trend of an each individual car brand and its price drop with the respect to the mileage and manufactured year. First, I have to collect data from outside source. I am using '1.2 Million Used Car Listings' provided by Evan Payne from Kaggle.

# %%
data = []

# %%
data = pd.read_csv("C:\\Users\\Danniel\\Documents\\GitHub\\DataScience_study\\used_car\\true_car_listings.csv")

# %% [markdown]
# Credit: https://www.kaggle.com/jpayne/852k-used-car-listings/version/2#true_car_listings.csv

# %%
data
# Out:
#         Price  Year  Mileage                 City State                Vin  \
# 0        6500  2011    74520               Tacoma    WA  WAUSFAFL1BA115313
# 1        9791  2009    61473             Chandler    AZ  WAUAF48H79K009975
# 2        7495  2006    42065              Norfolk    VA  WAUAF78E46A113560
# 3        9100  2006    47500             Columbus    OH  WAUDF78E26A027502
# 4        7795  2008    73289         Delray Beach    FL  WAUAF78E98A138571
# 5        5999  2007    76105               Berlin    NJ  WAUAF78E47A047125
# 6        7395  2007    67758                Davie    FL  WAUAF78E17A127126
# 7        4550  2006    88243          San Antonio    TX  WAUDF78E66A153202
# 8        6495  2007    73915        PINELLAS PARK    FL  WAUAF78E87A222492
# 9        3995  2004    78668       Virginia Beach    VA  WAUAC48H94K021661
# 10      17297  2015    14559               Lindon    UT  WAUFFAFL3FN029985
# 11       7450  2008    73275        Fredricksburg    VA  WAUAF78E38A127016
# 12      10788  2008    41072              Decatur    GA  WAUAF78E38A150473
# 13       9670  2011    86786              Margate    FL  WAUAFAFLXBN010578
# 14       7491  2009    83027      Fort Lauderdale    FL  WAUAF48H39K009231
# 15       8999  2008    56293              Seymour    CT  WAUBF98E68A047113
# 16      12995  2012    47093       N. Miami Beach    FL  WAUBFAFL6CN005688
# 17       7991  2006    65997                Plano    TX  WAUDF78E56A036825
# 18      12995  2011    43772            Glen Head    NY  WAUBFAFL2BN010966
# 19      12990  2011    61376          San Antonio    TX  WAUBFAFL1BN045952
# 20      15995  2014    52914                Selma    TX  WAUAFAFL6EN019590
# 21       7100  2007    87184  San Juan Capistrano    CA  WAUAF78E67A206968
# 22       9995  2011    74234             Columbia    TN  WAUAFAFL9BN009065
# 23       4995  2006    92592            Las Vegas    NV  WAUBC48H66K006848
# 24       7349  2006    64949           Woodbridge    VA  WAUDF78E86A054221
# 25       6700  2008    90106              Miramar    FL  WAUAF78E28A155454
# 26       9995  2010    68167                Doral    FL  WAUAFAFL2AN015546
# 27      10229  2009    68922            Las Vegas    NV  WAUAF48H69K010986
# 28       7988  2007    67438               Dallas    TX  WAUDF78E37A229086
# 29       6490  2006    77106            Pittsburg    CA  WAUKG78E96A040168
# ...       ...   ...      ...                  ...   ...                ...
# 739968  39900  2015    23700       Southern Pines    NC  WVGEP9BPXFD007454
# 739969  16995  2016    33310             Meridian    MS  3VWF17ATXGM608069
# 739970  34028  2016    30000             Valencia    CA  WVWUF7AU0GW021786
# 739971  42498  2017     9628               Austin    TX  WVGRF7BPXHD001567
# 739972  26590  2012    48150               Auburn    WA  WVWPF7AJ7CW328644
# 739973  42532  2017    13453               Yakima    WA  WVGRF7BP9HD003245
# 739974  40988  2015    14863            Bremerton    WA  WVGEF9BP4FD005895
# 739975  36806  2014    58030               Yakima    WA  WVGEP9BP6ED010883
# 739976  42998  2017     8800               Austin    TX  WVGRF7BP8HD004449
# 739977  42380  2015     4002          Cherry Hill    NJ  WVGEF9BP5FD002357
# 739978  16943  2012    46234              Weslaco    TX  3VWVA7AT1CM624814
# 739979  43995  2017    14568             Puyallup    WA  WVGRF7BPXHD001004
# 739980  10000  2001   135166               Tacoma    WA  3VWCD21C11M446076
# 739981  34730  2015    36064           Burlington    NJ  WVWLF7AU6FW164199
# 739982  52342  2016    11022              Danvers    MA  WVGEF9BP0GD011601
# 739983  33991  2016    14229              Seattle    WA  WVWLF7AU6GW118194
# 739984  46488  2016     8071            Beaverton    OR  WVGEF9BP1GD011591
# 739985  47991  2017    14478              Seattle    WA  WVGGF7BP0HD005246
# 739986  37791  2017     6906             Chandler    AZ  WVWVF7AU8HW133080
# 739987  29995  2012    43376           Santa Cruz    CA  WVWRF7AJ0CW333029
# 739988  47500  2016    14500            Baltimore    MD  WVGEF9BP8GD012866
# 739989  33988  2016    22472         White Plains    NY  WVWLF7AUXGW097589
# 739990  34495  2015    20990          Sioux Falls    SD  WVWLF7AU8FW179609
# 739991  49342  2016    21577               Naples    FL  WVGEP9BP8GD004067
# 739992  49995  2017     8731            Lyndhurst    NJ  WVGRF7BP3HD003676
# 739993  49995  2017    11460            Lyndhurst    NJ  WVGRF7BP4HD003346
# 739994  54740  2016    16439            Las Vegas    NV  WVGEP9BP2GD004467
# 739995  24995  2013    77880             Puyallup    WA  WVWRF7AJ0DW028213
# 739996  55101  2012   118635          San Antonio    TX  WVGEK9BP0CD011877
# 739997  12889  2015   999999      Missouri Valley    IA  3VW2K7AJ0FM279827
#
#               Make       Model
# 0             Audi       A44dr
# 1             Audi       A42dr
# 2             Audi       A44dr
# 3             Audi       A44dr
# 4             Audi       A44dr
# 5             Audi    A42007.5
# 6             Audi    A42007.5
# 7             Audi       A44dr
# 8             Audi    A42007.5
# 9             Audi      A42004
# 10            Audi      A42.0T
# 11            Audi       A44dr
# 12            Audi       A44dr
# 13            Audi       A44dr
# 14            Audi       A42dr
# 15            Audi       A44dr
# 16            Audi       A44dr
# 17            Audi       A44dr
# 18            Audi       A44dr
# 19            Audi       A44dr
# 20            Audi      A42.0T
# 21            Audi    A42007.5
# 22            Audi       A44dr
# 23            Audi       A42dr
# 24            Audi       A44dr
# 25            Audi       A44dr
# 26            Audi       A44dr
# 27            Audi       A42dr
# 28            Audi    A42007.5
# 29            Audi       A45dr
# ...            ...         ...
# 739968  Volkswagen  TouaregTDI
# 739969  Volkswagen      Beetle
# 739970  Volkswagen        Golf
# 739971  Volkswagen   TouaregV6
# 739972  Volkswagen        Golf
# 739973  Volkswagen   TouaregV6
# 739974  Volkswagen   TouaregV6
# 739975  Volkswagen  TouaregTDI
# 739976  Volkswagen   TouaregV6
# 739977  Volkswagen   TouaregV6
# 739978  Volkswagen   Beetle2dr
# 739979  Volkswagen   TouaregV6
# 739980  Volkswagen         New
# 739981  Volkswagen        Golf
# 739982  Volkswagen   TouaregV6
# 739983  Volkswagen        Golf
# 739984  Volkswagen   TouaregV6
# 739985  Volkswagen   TouaregV6
# 739986  Volkswagen        Golf
# 739987  Volkswagen        Golf
# 739988  Volkswagen   TouaregV6
# 739989  Volkswagen        Golf
# 739990  Volkswagen        Golf
# 739991  Volkswagen  TouaregTDI
# 739992  Volkswagen   TouaregV6
# 739993  Volkswagen   TouaregV6
# 739994  Volkswagen  TouaregTDI
# 739995  Volkswagen        Golf
# 739996  Volkswagen  Touareg4dr
# 739997  Volkswagen       Jetta
#
# [739998 rows x 8 columns]

# %%
print('Total length of the data : %d' %len(data['Make']))
# Out:
# Total length of the data : 852122

# %%
print('Total number of the car brands : %d' %len(Counter(data['Make'])))
# Out:
# Total number of the car brands : 58

# %%
Counter(data['Make'])
# Out:
# Counter({'Acura': 11049,
#          'Alfa': 44,
#          'AM': 19,
#          'Aston': 149,
#          'Audi': 12618,
#          'Bentley': 367,
#          'BMW': 32415,
#          'Buick': 12491,
#          'Cadillac': 15047,
#          'Chevrolet': 102268,
#          'Chrysler': 16357,
#          'Dodge': 34368,
#          'Ferrari': 345,
#          'FIAT': 1782,
#          'Fisker': 19,
#          'Ford': 110432,
#          'Freightliner': 11,
#          'Genesis': 141,
#          'Geo': 2,
#          'GMC': 29008,
#          'Honda': 50193,
#          'HUMMER': 949,
#          'Hyundai': 35837,
#          'INFINITI': 12258,
#          'Isuzu': 76,
#          'Jaguar': 2200,
#          'Jeep': 40373,
#          'Kia': 28636,
#          'Lamborghini': 121,
#          'Land': 4096,
#          'Lexus': 20641,
#          'Lincoln': 7120,
#          'Lotus': 42,
#          'Maserati': 1047,
#          'Maybach': 10,
#          'Mazda': 13365,
#          'McLaren': 47,
#          'Mercedes-Benz': 26323,
#          'Mercury': 1076,
#          'MINI': 4375,
#          'Mitsubishi': 4080,
#          'Nissan': 66250,
#          'Oldsmobile': 122,
#          'Plymouth': 51,
#          'Pontiac': 1783,
#          'Porsche': 4106,
#          'Ram': 19808,
#          'Rolls-Royce': 92,
#          'Saab': 260,
#          'Saturn': 963,
#          'Scion': 3043,
#          'smart': 713,
#          'Subaru': 16428,
#          'Suzuki': 334,
#          'Tesla': 231,
#          'Toyota': 77786,
#          'Volkswagen': 23249,
#          'Volvo': 5106})

# %% [markdown]
# There are about 80,000 individual data values about used cars, and 58 different car brands in the dataset. In order to make this data more general and useful, popular car brands are selected. According to 2018 US Automotive Brand Rankings – YTD, we are going to use only top 18 car brands according to their market share in the car industry.
#
# credit: http://www.goodcarbadcar.net/2018/10/u-s-auto-sales-brand-rankings-september-2018-ytd/

# %%
top_brands = pd.read_csv("C:\\Users\\Danniel\\Documents\\GitHub\\DataScience_study\\used_car\\us_top_18_brands_2018.csv")

# %%
top_brands
# Out:
#             Brand    Month  Change        YTD  YTD Change  Month Share  \
# 0            Ford  188,328  -11.52  1,808,326       -1.81        13.07
# 1          Toyota  178,501  -10.94  1,706,410        5.88        12.39
# 2       Chevrolet  159,171  -20.34  1,486,515       -1.96        11.05
# 3           Honda  119,157   -8.18  1,092,247       -2.08         8.27
# 4          Nissan  110,283  -13.29  1,019,433       -5.83         7.65
# 5            Jeep   83,764   14.11    746,194       19.92         5.81
# 6          Subaru   57,044    3.49    503,418        5.13         3.96
# 7         Hyundai   56,940    3.02    492,791       -0.77         3.95
# 8             Kia   51,503   -1.84    452,042       -1.29         3.57
# 9             Ram   56,447    9.21    416,661       -0.49         3.92
# 10            GMC   41,584  -12.14    395,926       -2.39         2.89
# 11          Dodge   42,101   40.63    359,728       -1.66         2.92
# 12     Volkswagen   30,555   -4.85    266,217        5.45         2.12
# 13  Mercedes-Benz   30,617  -15.57    254,698      -15.05         2.12
# 14          Mazda   21,257  -17.41    235,122        6.73         1.48
# 15            BMW   25,908    1.32    225,065        2.22         1.80
# 16          Lexus   24,597   -6.10    213,616       -2.42         1.71
# 17           Audi   19,350    1.77    167,165        5.39         1.34
#
#     YTD Share
# 0       13.87
# 1       13.09
# 2       11.40
# 3        8.38
# 4        7.82
# 5        5.72
# 6        3.86
# 7        3.78
# 8        3.47
# 9        3.20
# 10       3.04
# 11       2.76
# 12       2.04
# 13       1.95
# 14       1.80
# 15       1.73
# 16       1.64
# 17       1.28

# %%
data = data.loc[data['Make'].isin(list(top_brands['Brand']))]

# %%
data.head()
# Out:
#    Price  Year  Mileage          City State                Vin  Make  Model
# 0   6500  2011    74520        Tacoma    WA  WAUSFAFL1BA115313  Audi  A44dr
# 1   9791  2009    61473      Chandler    AZ  WAUAF48H79K009975  Audi  A42dr
# 2   7495  2006    42065       Norfolk    VA  WAUAF78E46A113560  Audi  A44dr
# 3   9100  2006    47500      Columbus    OH  WAUDF78E26A027502  Audi  A44dr
# 4   7795  2008    73289  Delray Beach    FL  WAUAF78E98A138571  Audi  A44dr

# %%
#resetting indexes from 0 to nth order
data.index = range(len(data))

# %%
data.head()
# Out:
#    Price  Year  Mileage          City State                Vin  Make  Model
# 0   6500  2011    74520        Tacoma    WA  WAUSFAFL1BA115313  Audi  A44dr
# 1   9791  2009    61473      Chandler    AZ  WAUAF48H79K009975  Audi  A42dr
# 2   7495  2006    42065       Norfolk    VA  WAUAF78E46A113560  Audi  A44dr
# 3   9100  2006    47500      Columbus    OH  WAUDF78E26A027502  Audi  A44dr
# 4   7795  2008    73289  Delray Beach    FL  WAUAF78E98A138571  Audi  A44dr

# %%
Counter(data['Make'])
# Out:
# Counter({'Audi': 12618,
#          'BMW': 32415,
#          'Chevrolet': 102268,
#          'Dodge': 34368,
#          'Ford': 110432,
#          'GMC': 29008,
#          'Honda': 50193,
#          'Hyundai': 35837,
#          'Jeep': 40373,
#          'Kia': 28636,
#          'Lexus': 20641,
#          'Mazda': 13365,
#          'Mercedes-Benz': 26323,
#          'Nissan': 66250,
#          'Ram': 19808,
#          'Subaru': 16428,
#          'Toyota': 77786,
#          'Volkswagen': 23249})

# %% [markdown]
# Now it seems that our data rows only contain the car brands correspondent to the YTD chart.
# Since each car brand holds a different data size, I choose 1,000 sample size from each car brand.

# %%
sample_data = pd.DataFrame({'Price': [],
                            'Year': [],
                            'Mileage': [],
                            'Make': []})

# %%
j = 0

for i in range(len(data)-2):
    if data['Make'][i] != data['Make'][i+1]:
        sample_data = sample_data.append(data[j:i].sample(n=1000))
        j = i
    if i == len(data)-3:
        sample_data = sample_data.append(data[j:i].sample(n=1000))
# Out:
# 739995

# %%
#resetting indexes from 0 to nth order
sample_data.index = range(len(sample_data))

# %%
sample_data.head()
# Out:
#          City  Make   Mileage      Model    Price State                Vin  \
# 0  Fort Myers  Audi   38899.0         A8  50995.0    FL  WAU32AFD7FN025218
# 1       Ewing  Audi   34991.0     A42.0T  26995.0    NJ  WAUFFAFL4FN012192
# 2       Colma  Audi   34268.0  Q5quattro  24999.0    CA  WA1CFAFP2CA068962
# 3     Sanford  Audi    6469.0     A62.0T  42987.0    FL  WAUG8AFC7HN048346
# 4  Sykesville  Audi  116685.0      A44dr   8595.0    MD  WAUSF78K49N012672
#
#      Year
# 0  2015.0
# 1  2015.0
# 2  2012.0
# 3  2017.0
# 4  2009.0

# %%
Counter(sample_data['Make'])
# Out:
# Counter({'Audi': 1000,
#          'BMW': 1000,
#          'Chevrolet': 1000,
#          'Dodge': 1000,
#          'Ford': 1000,
#          'GMC': 1000,
#          'Honda': 1000,
#          'Hyundai': 1000,
#          'Jeep': 1000,
#          'Kia': 1000,
#          'Lexus': 1000,
#          'Mazda': 1000,
#          'Mercedes-Benz': 1000,
#          'Nissan': 1000,
#          'Ram': 1000,
#          'Subaru': 1000,
#          'Toyota': 1000,
#          'Volkswagen': 1000})

# %% [markdown]
# After sampling with the size n = 1,000, we can see that each car brands now has sample data of 1,000.

# %%
r = 0
correlation_list = []
for i in range(len(sample_data)-2):
    
    xs_mileage = []
    ys_price = []
    
    if sample_data['Make'][i] != sample_data['Make'][i+1] or i == len(data)-3:
        
        xs_mileage = [sample_data['Mileage'][m]
         for m in range(r,i)]

        ys_price = [sample_data['Price'][j]
         for j in range(r,i)]
        
        r = i
        
        correlation_list.append([sample_data['Make'][r],np.corrcoef(xs_mileage, ys_price)[0][1]])
        plt.scatter(xs_mileage,ys_price,label = sample_data['Make'][r])
        plt.title('Price vs Mileage')
        plt.xlabel('Mileage')
        plt.ylabel('Price')
        plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

r = 0
for i in range(len(sample_data)-2):

    xs_year = []
    ys_price = []
    
    if sample_data['Make'][i] != sample_data['Make'][i+1] or i == len(data)-3:
        
        xs_year = [sample_data['Year'][k]
         for k in range(r,i)]

        ys_price = [sample_data['Price'][j]
         for j in range(r,i)]
        
        r = i
        
        correlation_list.append([sample_data['Make'][r],np.corrcoef(xs_year, ys_price)[0][1]])
        
        plt.scatter(xs_year,ys_price,label = sample_data['Make'][r])
        plt.title('Price vs Year')
        plt.xlabel('Year')
        plt.ylabel('Price')
        plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# However, it seems that there are several outliers disturbing the scale of our scatter plots. We can improve on this by replacing outliers with the median data.

# %%
from numpy.polynomial import Polynomial

# %%
r = 0
gradient_mileage = []
for i in range(len(sample_data)-2):
    
    xs_mileage = []
    ys_price = []
    
    if sample_data['Make'][i] != sample_data['Make'][i+1] or i == len(data)-3:
        
        xs_mileage = [sample_data['Mileage'][m]
         for m in range(r,i)]

        #setting a boundary which contains 98% of the data
        q_lower_mileage = np.percentile(xs_mileage, 1)
        q_higher_mileage = np.percentile(xs_mileage, 99)
        
        for p in range(len(xs_mileage)):
            if xs_mileage[p] > q_higher_mileage or xs_mileage[p] < q_lower_mileage:
                xs_mileage[p] = np.median(xs_mileage)
                
        ys_price = [sample_data['Price'][j]
         for j in range(r,i)]
        
        q_lower_price = np.percentile(ys_price, 1)
        q_higher_price = np.percentile(ys_price, 99)
        
        for p in range(len(ys_price)):
            if ys_price[p] > q_higher_price or ys_price[p] < q_lower_price:
                ys_price[p] = np.median(ys_price)
        
        r = i
        
        gradient_mileage.append([np.polyfit(xs_mileage,ys_price,1),sample_data['Make'][r]])
        plt.scatter(xs_mileage,ys_price,label = sample_data['Make'][r])
        plt.title('Price vs Mileage')
        plt.xlabel('Mileage')
        plt.ylabel('Price')
        plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

r = 0
gradient_year = []
for i in range(len(sample_data)-2):

    xs_year = []
    ys_price = []
    
    if sample_data['Make'][i] != sample_data['Make'][i+1] or i == len(data)-3:
        
        xs_year = [sample_data['Year'][k]
         for k in range(r,i)]
        

        ys_price = [sample_data['Price'][j]
         for j in range(r,i)]
        
        q_lower_price = np.percentile(ys_price, 1)
        q_higher_price = np.percentile(ys_price, 99)
        
        for p in range(len(ys_price)):
            if ys_price[p] > q_higher_price or ys_price[p] < q_lower_price:
                ys_price[p] = np.median(ys_price)
        
        r = i
        
        correlation_list.append([sample_data['Make'][r],np.corrcoef(xs_year, ys_price)[0][1]])
        
        gradient_year.append([np.polyfit(xs_year,ys_price,1),sample_data['Make'][r]])
        plt.scatter(xs_year,ys_price,label = sample_data['Make'][r])
        plt.title('Price vs Year')
        plt.xlabel('Year')
        plt.ylabel('Price')
        plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# By replacing several outliers with median values, the graph appears to be trimed(although it is still chaotic since 18 scatter plots were on the same axis)...
# Now we have to get a best fit line which describes the trend of the data. Since I do not want my graph to overfit, I am going to compare 1st, 2nd and 3rd order of best fit line.

# %%
r = 0
for i in range(len(sample_data)-2):
    
    xs_mileage = []
    ys_price = []
    
    if sample_data['Make'][i] != sample_data['Make'][i+1] or i == len(data)-3:
        
        xs_mileage = [sample_data['Mileage'][m]
         for m in range(r,i)]

        #setting a boundary which contains 98% of the data
        q_lower_mileage = np.percentile(xs_mileage, 1)
        q_higher_mileage = np.percentile(xs_mileage, 99)
        
        for p in range(len(xs_mileage)):
            if xs_mileage[p] > q_higher_mileage or xs_mileage[p] < q_lower_mileage:
                xs_mileage[p] = np.median(xs_mileage)
                
        ys_price = [sample_data['Price'][j]
         for j in range(r,i)]
        
        q_lower_price = np.percentile(ys_price, 1)
        q_higher_price = np.percentile(ys_price, 99)
        
        for p in range(len(ys_price)):
            if ys_price[p] > q_higher_price or ys_price[p] < q_lower_price:
                ys_price[p] = np.median(ys_price)
        
        r = i
        
        plt.scatter(xs_mileage,ys_price,label = sample_data['Make'][r])
        p = Polynomial.fit(xs_mileage, ys_price, 1)
        plt.plot(*p.linspace())
        plt.title('Price vs Mileage #1')
        plt.xlabel('Mileage')
        plt.ylabel('Price')
        plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
        
r = 0
for i in range(len(sample_data)-2):
    
    xs_mileage = []
    ys_price = []
    
    if sample_data['Make'][i] != sample_data['Make'][i+1] or i == len(data)-3:
        
        xs_mileage = [sample_data['Mileage'][m]
         for m in range(r,i)]

        #setting a boundary which contains 98% of the data
        q_lower_mileage = np.percentile(xs_mileage, 1)
        q_higher_mileage = np.percentile(xs_mileage, 99)
        
        for p in range(len(xs_mileage)):
            if xs_mileage[p] > q_higher_mileage or xs_mileage[p] < q_lower_mileage:
                xs_mileage[p] = np.median(xs_mileage)
                
        ys_price = [sample_data['Price'][j]
         for j in range(r,i)]
        
        q_lower_price = np.percentile(ys_price, 1)
        q_higher_price = np.percentile(ys_price, 99)
        
        for p in range(len(ys_price)):
            if ys_price[p] > q_higher_price or ys_price[p] < q_lower_price:
                ys_price[p] = np.median(ys_price)
        
        r = i
        
        plt.scatter(xs_mileage,ys_price,label = sample_data['Make'][r])
        p = Polynomial.fit(xs_mileage, ys_price, 2)
        plt.plot(*p.linspace())
        plt.title('Price vs Mileage #2')
        plt.xlabel('Mileage')
        plt.ylabel('Price')
        plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
        
        
r = 0
for i in range(len(sample_data)-2):
    
    xs_mileage = []
    ys_price = []
    
    if sample_data['Make'][i] != sample_data['Make'][i+1] or i == len(data)-3:
        
        xs_mileage = [sample_data['Mileage'][m]
         for m in range(r,i)]

        #setting a boundary which contains 98% of the data
        q_lower_mileage = np.percentile(xs_mileage, 1)
        q_higher_mileage = np.percentile(xs_mileage, 99)
        
        for p in range(len(xs_mileage)):
            if xs_mileage[p] > q_higher_mileage or xs_mileage[p] < q_lower_mileage:
                xs_mileage[p] = np.median(xs_mileage)
                
        ys_price = [sample_data['Price'][j]
         for j in range(r,i)]
        
        q_lower_price = np.percentile(ys_price, 1)
        q_higher_price = np.percentile(ys_price, 99)
        
        for p in range(len(ys_price)):
            if ys_price[p] > q_higher_price or ys_price[p] < q_lower_price:
                ys_price[p] = np.median(ys_price)
        
        r = i
        
        plt.scatter(xs_mileage,ys_price,label = sample_data['Make'][r])
        p = Polynomial.fit(xs_mileage, ys_price, 3)
        plt.plot(*p.linspace())
        plt.title('Price vs Mileage #3')
        plt.xlabel('Mileage')
        plt.ylabel('Price')
        plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# For the fit line 2 and 3, both graphs showed an increase after passing their local minimum point. Therefore quadratic and cubic best fit line will not be considered for now. Although exponential decay graph seems to fit better than linear, for now I am going to use linear fit line to demonstrate how well or bad it can get.

# %%
gradient_mileage
# Out:
# [[array([-2.65205025e-01,  4.07245076e+04]), 'Audi'],
#  [array([-2.40684623e-01,  3.77301517e+04]), 'BMW'],
#  [array([-1.06191342e-01,  2.71087578e+04]), 'Chevrolet'],
#  [array([-9.02147164e-02,  2.31746183e+04]), 'Dodge'],
#  [array([-1.08696897e-01,  2.72514199e+04]), 'Ford'],
#  [array([-1.64511594e-01,  3.77965714e+04]), 'GMC'],
#  [array([-9.61494254e-02,  2.19862910e+04]), 'Honda'],
#  [array([-9.03831300e-02,  1.86613784e+04]), 'Hyundai'],
#  [array([-1.33759095e-01,  2.81818755e+04]), 'Jeep'],
#  [array([-8.78428410e-02,  1.92403278e+04]), 'Kia'],
#  [array([-1.95334754e-01,  3.73627970e+04]), 'Lexus'],
#  [array([-1.20192653e-01,  2.16474345e+04]), 'Mazda'],
#  [array([-2.99930271e-01,  4.56053577e+04]), 'Mercedes-Benz'],
#  [array([-1.03973953e-01,  2.12615106e+04]), 'Nissan'],
#  [array([-7.55871547e-02,  3.39826098e+04]), 'Ram'],
#  [array([-1.20892648e-01,  2.51221430e+04]), 'Subaru'],
#  [array([-9.30171423e-02,  2.42909028e+04]), 'Toyota']]

# %%
from pylab import rcParams

# %%
def bar_price_mileage(c):
    rcParams['figure.figsize'] = 20, 10
    M_Data = pd.DataFrame({'price': [(gradient_mileage[i][0][1]+gradient_mileage[i][0][0]*c)/gradient_mileage[i][0][1]*100
                                    for i in range(len(gradient_mileage))]})
    M_Data.index = [gradient_mileage[i][1]
                   for i in range(len(gradient_mileage))]
    
    M_Data = M_Data.sort_values(by='price',ascending=True)
    
    fig, ax = plt.subplots()
   
    ax.bar(M_Data.index, M_Data["price"], color="C0")
    plt.ylim([0,100])
    plt.ylabel('Expected percentage price remaining')
    ax.tick_params(axis="y", colors="C0")
    plt.show()

# %% [markdown]
# Since we have gradeints for each car brand's price-mileage graphs, we can estimate the price drop with respect to mileage.

# %%
import ipywidgets as wg
from IPython.display import display

# %%
c_slide = wg.FloatSlider(value = 0, min = 3000, max = 130000, step = 1500,description = 'Mileage')

# %%
wg.interact(bar_price_mileage, c = c_slide)
# Out:
# interactive(children=(FloatSlider(value=3000.0, description='Mileage', max=130000.0, min=3000.0, step=1500.0),…
# <function __main__.bar_price_mileage(c)>

# %% [markdown]
# By adjusting the slider, we can estimate the expected percentage price remaining.
